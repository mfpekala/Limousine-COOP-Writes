# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('fill_factor.csv')
x = list(df["ff"])
before = list(df["before"])
after = list(df["after"])

# %%
# Plot all of these using matplotlib
plt.plot(x, before, label="Before")
plt.plot(x, after, label="After")
plt.xlabel("Fill Factor")
plt.ylabel("Segment Count")
plt.title("Segment Count vs Fill Factor")
plt.legend()
plt.show()
